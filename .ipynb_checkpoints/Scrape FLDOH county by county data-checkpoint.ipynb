# %%
import requests, json, csv, datetime
from collections import OrderedDict

# %%
url = "https://services1.arcgis.com/CY1LXxl9zlJeBuRZ/ArcGIS/rest/services/Florida_COVID19_Cases_by_County/FeatureServer/0/query?f=json&where=1%3D1&returnGeometry=false&outFields=*"
content = requests.get(url).content
data = json.loads(content)
timestamp = datetime.datetime.now().strftime("%Y-%m-%d_%H%M")

# %%
masterlist = []
for i, county in enumerate(data['features']):
    countyname = data['features'][i]['attributes']['County']
    countypeople = data['features'][i]['attributes']['Cases']
    for person in countypeople.split("||"):
        line = OrderedDict()
        line['county'] = countyname
        line['gender'] = person.split(",")[0].split(":")[1].strip()
        line['age'] = person.split(",")[1].split(":")[1].strip()
        line['travel'] = person.split(",")[2].split("?")[1].strip()
        masterlist.append(line)
# Out:
# [OrderedDict([('county', 'Alachua'),
#               ('gender', 'Male'),
#               ('age', '24'),
#               ('travel', 'Yes - PORTUGAL')]),
#  OrderedDict([('county', 'Broward'),
#               ('gender', 'Female'),
#               ('age', '20'),
#               ('travel', 'Yes - IRELAND')]),
#  OrderedDict([('county', 'Broward'),
#               ('gender', 'Male'),
#               ('age', '39'),
#               ('travel', 'Unknown')]),
#  OrderedDict([('county', 'Broward'),
#               ('gender', 'Female'),
#               ('age', '68'),
#               ('travel', 'No')]),
#  OrderedDict([('county', 'Broward'),
#               ('gender', 'Male'),
#               ('age', '59'),
#               ('travel', 'No')]),
#  OrderedDict([('county', 'Broward'),
#               ('gender', 'Female'),
#               ('age', '20'),
#               ('travel', 'Yes - IRELAND')]),
#  OrderedDict([('county', 'Broward'),
#               ('gender', 'Male'),
#               ('age', '75'),
#               ('travel', 'No')]),
#  OrderedDict([('county', 'Broward'),
#               ('gender', 'Male'),
#               ('age', '60'),
#               ('travel', 'No')]),
#  OrderedDict([('county', 'Broward'),
#               ('gender', 'Male'),
#               ('age', '21'),
#               ('travel', 'Yes - ITALY; SPAIN')]),
#  OrderedDict([('county', 'Broward'),
#               ('gender', 'Female'),
#               ('age', '83'),
#               ('travel', 'No')]),
#  OrderedDict([('county', 'Broward'),
#               ('gender', 'Female'),
#               ('age', '19'),
#               ('travel', 'Yes - IRELAND')]),
#  OrderedDict([('county', 'Broward'),
#               ('gender', 'Male'),
#               ('age', '61'),
#               ('travel', 'Yes - ITALY')]),
#  OrderedDict([('county', 'Broward'),
#               ('gender', 'Male'),
#               ('age', '67'),
#               ('travel', 'No')]),
#  OrderedDict([('county', 'Broward'),
#               ('gender', 'Female'),
#               ('age', '68'),
#               ('travel', 'No')]),
#  OrderedDict([('county', 'Broward'),
#               ('gender', 'Male'),
#               ('age', '60'),
#               ('travel', 'Unknown')]),
#  OrderedDict([('county', 'Broward'),
#               ('gender', 'Male'),
#               ('age', '70'),
#               ('travel', 'Unknown')]),
#  OrderedDict([('county', 'Broward'),
#               ('gender', 'Male'),
#               ('age', '63'),
#               ('travel', 'No')]),
#  OrderedDict([('county', 'Broward'),
#               ('gender', 'Female'),
#               ('age', '20'),
#               ('travel', 'Yes - IRELAND')]),
#  OrderedDict([('county', 'Broward'),
#               ('gender', 'Female'),
#               ('age', '19'),
#               ('travel', 'Yes - IRELAND')]),
#  OrderedDict([('county', 'Broward'),
#               ('gender', 'Female'),
#               ('age', '22'),
#               ('travel', 'Yes - IRELAND')]),
#  OrderedDict([('county', 'Broward'),
#               ('gender', 'Male'),
#               ('age', '83'),
#               ('travel', 'Unknown')]),
#  OrderedDict([('county', 'Broward'),
#               ('gender', 'Male'),
#               ('age', '30'),
#               ('travel', 'Yes - FL; GA')]),
#  OrderedDict([('county', 'Broward'),
#               ('gender', 'Male'),
#               ('age', '74'),
#               ('travel', 'No')]),
#  OrderedDict([('county', 'Broward'),
#               ('gender', 'Male'),
#               ('age', '65'),
#               ('travel', 'Yes - DC')]),
#  OrderedDict([('county', 'Broward'),
#               ('gender', 'Male'),
#               ('age', '36'),
#               ('travel', 'No')]),
#  OrderedDict([('county', 'Broward'),
#               ('gender', 'Female'),
#               ('age', '54'),
#               ('travel', 'Unknown')]),
#  OrderedDict([('county', 'Broward'),
#               ('gender', 'Female'),
#               ('age', '26'),
#               ('travel', 'Yes - TRINIDAD AND TOBAGO')]),
#  OrderedDict([('county', 'Broward'),
#               ('gender', 'Male'),
#               ('age', '65'),
#               ('travel', 'No')]),
#  OrderedDict([('county', 'Broward'),
#               ('gender', 'Female'),
#               ('age', '19'),
#               ('travel', 'Yes - IRELAND')]),
#  OrderedDict([('county', 'Broward'),
#               ('gender', 'Male'),
#               ('age', '65'),
#               ('travel', 'No')]),
#  OrderedDict([('county', 'Broward'),
#               ('gender', 'Male'),
#               ('age', '66'),
#               ('travel', 'No')]),
#  OrderedDict([('county', 'Broward'),
#               ('gender', 'Female'),
#               ('age', '27'),
#               ('travel', 'No')]),
#  OrderedDict([('county', 'Broward'),
#               ('gender', 'Female'),
#               ('age', '63'),
#               ('travel', 'Unknown')]),
#  OrderedDict([('county', 'Broward'),
#               ('gender', 'Male'),
#               ('age', '64'),
#               ('travel', 'Yes - FRANCE; GA; NC; SPAIN')]),
#  OrderedDict([('county', 'Broward'),
#               ('gender', 'Female'),
#               ('age', '52'),
#               ('travel', 'Yes - FRANCE')]),
#  OrderedDict([('county', 'Broward'),
#               ('gender', 'Female'),
#               ('age', '20'),
#               ('travel', 'Yes - IRELAND')]),
#  OrderedDict([('county', 'Broward'),
#               ('gender', 'Male'),
#               ('age', '58'),
#               ('travel', 'No')]),
#  OrderedDict([('county', 'Broward'),
#               ('gender', 'Male'),
#               ('age', '65'),
#               ('travel', 'Unknown')]),
#  OrderedDict([('county', 'Broward'),
#               ('gender', 'Female'),
#               ('age', '51'),
#               ('travel', 'Unknown')]),
#  OrderedDict([('county', 'Charlotte'),
#               ('gender', 'Female'),
#               ('age', '54'),
#               ('travel', 'Yes - EGYPT; ISRAEL')]),
#  OrderedDict([('county', 'Citrus'),
#               ('gender', 'Female'),
#               ('age', '60'),
#               ('travel', 'Yes - FL; SWITZERLAND')]),
#  OrderedDict([('county', 'Clay'),
#               ('gender', 'Male'),
#               ('age', '70'),
#               ('travel', 'No')]),
#  OrderedDict([('county', 'Clay'),
#               ('gender', 'Female'),
#               ('age', '55'),
#               ('travel', 'No')]),
#  OrderedDict([('county', 'Clay'),
#               ('gender', 'Male'),
#               ('age', '57'),
#               ('travel', 'No')]),
#  OrderedDict([('county', 'Collier'),
#               ('gender', 'Female'),
#               ('age', '64'),
#               ('travel', 'Yes - EGYPT')]),
#  OrderedDict([('county', 'Collier'),
#               ('gender', 'Female'),
#               ('age', '49'),
#               ('travel', 'Unknown')]),
#  OrderedDict([('county', 'Collier'),
#               ('gender', 'Female'),
#               ('age', '68'),
#               ('travel', 'Yes - EGYPT')]),
#  OrderedDict([('county', 'Collier'),
#               ('gender', 'Male'),
#               ('age', '28'),
#               ('travel', 'Yes - ITALY')]),
#  OrderedDict([('county', 'Collier'),
#               ('gender', 'Male'),
#               ('age', '76'),
#               ('travel', 'Yes - NY')]),
#  OrderedDict([('county', 'Collier'),
#               ('gender', 'Male'),
#               ('age', '73'),
#               ('travel', 'Yes - EGYPT')]),
#  OrderedDict([('county', 'Dade'),
#               ('gender', 'Male'),
#               ('age', '66'),
#               ('travel', 'Unknown')]),
#  OrderedDict([('county', 'Dade'),
#               ('gender', 'Male'),
#               ('age', '73'),
#               ('travel', 'No')]),
#  OrderedDict([('county', 'Dade'),
#               ('gender', 'Female'),
#               ('age', '77'),
#               ('travel',
#                'Yes - EGYPT; IRAN (ISLAMIC REP. OF); UNITED ARAB EMIRATES')]),
#  OrderedDict([('county', 'Dade'),
#               ('gender', 'Male'),
#               ('age', '42'),
#               ('travel', 'Yes - FRANCE')]),
#  OrderedDict([('county', 'Dade'),
#               ('gender', 'Male'),
#               ('age', '42'),
#               ('travel', 'Yes - SPAIN')]),
#  OrderedDict([('county', 'Dade'),
#               ('gender', 'Male'),
#               ('age', '56'),
#               ('travel', 'Yes - IRAN (ISLAMIC REP. OF)')]),
#  OrderedDict([('county', 'Dade'),
#               ('gender', 'Male'),
#               ('age', '28'),
#               ('travel', 'No')]),
#  OrderedDict([('county', 'Dade'),
#               ('gender', 'Female'),
#               ('age', '25'),
#               ('travel', 'Yes - SPAIN')]),
#  OrderedDict([('county', 'Dade'),
#               ('gender', 'Male'),
#               ('age', '43'),
#               ('travel', 'Yes - UT')]),
#  OrderedDict([('county', 'Dade'),
#               ('gender', 'Female'),
#               ('age', '39'),
#               ('travel', 'Yes - FL; NY')]),
#  OrderedDict([('county', 'Dade'),
#               ('gender', 'Male'),
#               ('age', '37'),
#               ('travel', 'Yes - EL SALVADOR; FL; MEXICO; SPAIN')]),
#  OrderedDict([('county', 'Dade'),
#               ('gender', 'Female'),
#               ('age', '45'),
#               ('travel', 'No')]),
#  OrderedDict([('county', 'Dade'),
#               ('gender', 'Male'),
#               ('age', '18'),
#               ('travel', 'Unknown')]),
#  OrderedDict([('county', 'Dade'),
#               ('gender', 'Male'),
#               ('age', '20'),
#               ('travel', 'Yes - SPAIN')]),
#  OrderedDict([('county', 'Dade'),
#               ('gender', 'Female'),
#               ('age', '66'),
#               ('travel', 'Unknown')]),
#  OrderedDict([('county', 'Dade'),
#               ('gender', 'Male'),
#               ('age', '29'),
#               ('travel', 'Unknown')]),
#  OrderedDict([('county', 'Dade'),
#               ('gender', 'Female'),
#               ('age', '58'),
#               ('travel', 'Yes - ITALY; SPAIN')]),
#  OrderedDict([('county', 'Dade'),
#               ('gender', 'Male'),
#               ('age', '56'),
#               ('travel', 'Unknown')]),
#  OrderedDict([('county', 'Dade'),
#               ('gender', 'Male'),
#               ('age', '51'),
#               ('travel', 'No')]),
#  OrderedDict([('county', 'Dade'),
#               ('gender', 'Female'),
#               ('age', '30'),
#               ('travel', 'Unknown')]),
#  OrderedDict([('county', 'Dade'),
#               ('gender', 'Female'),
#               ('age', '42'),
#               ('travel', 'Unknown')]),
#  OrderedDict([('county', 'Dade'),
#               ('gender', 'Male'),
#               ('age', '62'),
#               ('travel', 'No')]),
#  OrderedDict([('county', 'Dade'),
#               ('gender', 'Male'),
#               ('age', '39'),
#               ('travel', 'Unknown')]),
#  OrderedDict([('county', 'Duval'),
#               ('gender', 'Male'),
#               ('age', '88'),
#               ('travel', 'No')]),
#  OrderedDict([('county', 'Duval'),
#               ('gender', 'Male'),
#               ('age', '66'),
#               ('travel', 'No')]),
#  OrderedDict([('county', 'Duval'),
#               ('gender', 'Male'),
#               ('age', '83'),
#               ('travel', 'No')]),
#  OrderedDict([('county', 'Duval'),
#               ('gender', 'Male'),
#               ('age', '57'),
#               ('travel', 'Yes - FL; UNKNOWN')]),
#  OrderedDict([('county', 'Hillsborough'),
#               ('gender', 'Female'),
#               ('age', '29'),
#               ('travel', 'Yes - ITALY')]),
#  OrderedDict([('county', 'Hillsborough'),
#               ('gender', 'Female'),
#               ('age', '32'),
#               ('travel', 'Yes - CO')]),
#  OrderedDict([('county', 'Hillsborough'),
#               ('gender', 'Male'),
#               ('age', '47'),
#               ('travel', 'Yes - CO')]),
#  OrderedDict([('county', 'Hillsborough'),
#               ('gender', 'Male'),
#               ('age', '17'),
#               ('travel', 'No')]),
#  OrderedDict([('county', 'Hillsborough'),
#               ('gender', 'Female'),
#               ('age', '49'),
#               ('travel', 'Yes - FL; IRELAND')]),
#  OrderedDict([('county', 'Lake'),
#               ('gender', 'Female'),
#               ('age', '75'),
#               ('travel', 'Yes - FL; NY')]),
#  OrderedDict([('county', 'Lee'),
#               ('gender', 'Male'),
#               ('age', '77'),
#               ('travel', 'No')]),
#  OrderedDict([('county', 'Lee'),
#               ('gender', 'Female'),
#               ('age', '77'),
#               ('travel', 'Yes - DOMINICAN REPUBLIC')]),
#  OrderedDict([('county', 'Lee'),
#               ('gender', 'Female'),
#               ('age', '72'),
#               ('travel', 'Unknown')]),
#  OrderedDict([('county', 'Lee'),
#               ('gender', 'Male'),
#               ('age', '77'),
#               ('travel', 'Yes - DOMINICAN REPUBLIC')]),
#  OrderedDict([('county', 'Manatee'),
#               ('gender', 'Male'),
#               ('age', '63'),
#               ('travel', 'No')]),
#  OrderedDict([('county', 'Manatee'),
#               ('gender', 'Female'),
#               ('age', '62'),
#               ('travel', 'No')]),
#  OrderedDict([('county', 'Manatee'),
#               ('gender', 'Female'),
#               ('age', '81'),
#               ('travel', 'Yes - EGYPT')]),
#  OrderedDict([('county', 'Manatee'),
#               ('gender', 'Male'),
#               ('age', '70'),
#               ('travel', 'Unknown')]),
#  OrderedDict([('county', 'Manatee'),
#               ('gender', 'Female'),
#               ('age', '67'),
#               ('travel', 'No')]),
#  OrderedDict([('county', 'Nassau'),
#               ('gender', 'Male'),
#               ('age', '68'),
#               ('travel', 'Yes - GERMANY; MA')]),
#  OrderedDict([('county', 'Okaloosa'),
#               ('gender', 'Female'),
#               ('age', '61'),
#               ('travel', 'Yes - CA; FL; MEXICO')]),
#  OrderedDict([('county', 'Orange'),
#               ('gender', 'Female'),
#               ('age', '79'),
#               ('travel', 'Unknown')]),
#  OrderedDict([('county', 'Orange'),
#               ('gender', 'Female'),
#               ('age', '48'),
#               ('travel', 'No')]),
#  OrderedDict([('county', 'Orange'),
#               ('gender', 'Male'),
#               ('age', '41'),
#               ('travel', 'No')]),
#  OrderedDict([('county', 'Orange'),
#               ('gender', 'Female'),
#               ('age', '48'),
#               ('travel', 'Unknown')]),
#  OrderedDict([('county', 'Osceola'),
#               ('gender', 'Male'),
#               ('age', '31'),
#               ('travel', 'Yes - BRAZIL')]),
#  OrderedDict([('county', 'Osceola'),
#               ('gender', 'Female'),
#               ('age', '47'),
#               ('travel', 'Unknown')]),
#  OrderedDict([('county', 'Osceola'),
#               ('gender', 'Male'),
#               ('age', '48'),
#               ('travel', 'Yes - SWITZERLAND')]),
#  OrderedDict([('county', 'Osceola'),
#               ('gender', 'Male'),
#               ('age', '54'),
#               ('travel', 'No')]),
#  OrderedDict([('county', 'Palm Beach'),
#               ('gender', 'Male'),
#               ('age', '37'),
#               ('travel', 'Yes - NY')]),
#  OrderedDict([('county', 'Palm Beach'),
#               ('gender', 'Female'),
#               ('age', '76'),
#               ('travel', 'Unknown')]),
#  OrderedDict([('county', 'Palm Beach'),
#               ('gender', 'Female'),
#               ('age', '59'),
#               ('travel', 'Yes - NY')]),
#  OrderedDict([('county', 'Palm Beach'),
#               ('gender', 'Male'),
#               ('age', '62'),
#               ('travel', 'Unknown')]),
#  OrderedDict([('county', 'Palm Beach'),
#               ('gender', 'Male'),
#               ('age', '65'),
#               ('travel', 'Yes - NY')]),
#  OrderedDict([('county', 'Palm Beach'),
#               ('gender', 'Male'),
#               ('age', '73'),
#               ('travel', 'Yes - Egypt; Germany')]),
#  OrderedDict([('county', 'Palm Beach'),
#               ('gender', 'Male'),
#               ('age', '74'),
#               ('travel', 'Yes - BELGIUM; FL')]),
#  OrderedDict([('county', 'Palm Beach'),
#               ('gender', 'Male'),
#               ('age', '66'),
#               ('travel', 'Unknown')]),
#  OrderedDict([('county', 'Pasco'),
#               ('gender', 'Male'),
#               ('age', '67'),
#               ('travel', 'Yes - FL; NY')]),
#  OrderedDict([('county', 'Pasco'),
#               ('gender', 'Male'),
#               ('age', '46'),
#               ('travel', 'No')]),
#  OrderedDict([('county', 'Pinellas'),
#               ('gender', 'Male'),
#               ('age', '58'),
#               ('travel', 'Unknown')]),
#  OrderedDict([('county', 'Pinellas'),
#               ('gender', 'Male'),
#               ('age', '64'),
#               ('travel', 'Yes - EGYPT')]),
#  OrderedDict([('county', 'Pinellas'),
#               ('gender', 'Male'),
#               ('age', '58'),
#               ('travel', 'Unknown')]),
#  OrderedDict([('county', 'Pinellas'),
#               ('gender', 'Male'),
#               ('age', '67'),
#               ('travel', 'Yes - EGYPT')]),
#  OrderedDict([('county', 'Santa Rosa'),
#               ('gender', 'Male'),
#               ('age', '71'),
#               ('travel', 'Yes - EGYPT; ISRAEL; JORDAN')]),
#  OrderedDict([('county', 'Sarasota'),
#               ('gender', 'Male'),
#               ('age', '87'),
#               ('travel', 'No')]),
#  OrderedDict([('county', 'Sarasota'),
#               ('gender', 'Male'),
#               ('age', '80'),
#               ('travel', 'No')]),
#  OrderedDict([('county', 'Sarasota'),
#               ('gender', 'Female'),
#               ('age', '50'),
#               ('travel', 'Yes - NY')]),
#  OrderedDict([('county', 'Seminole'),
#               ('gender', 'Male'),
#               ('age', '68'),
#               ('travel', 'Yes - EGYPT; JORDAN')]),
#  OrderedDict([('county', 'Seminole'),
#               ('gender', 'Female'),
#               ('age', '68'),
#               ('travel', 'Yes - EGYPT; JORDAN')]),
#  OrderedDict([('county', 'Seminole'),
#               ('gender', 'Female'),
#               ('age', '43'),
#               ('travel', 'Unknown')]),
#  OrderedDict([('county', 'Seminole'),
#               ('gender', 'Male'),
#               ('age', '47'),
#               ('travel', 'Unknown')]),
#  OrderedDict([('county', 'St. Johns'),
#               ('gender', 'Female'),
#               ('age', '64'),
#               ('travel', 'No')]),
#  OrderedDict([('county', 'Volusia'),
#               ('gender', 'Female'),
#               ('age', '70'),
#               ('travel', 'Yes - EGYPT; JORDAN')]),
#  OrderedDict([('county', 'Volusia'),
#               ('gender', 'Female'),
#               ('age', '66'),
#               ('travel', 'Yes - EGYPT; GERMANY; ISRAEL')]),
#  OrderedDict([('county', 'Volusia'),
#               ('gender', 'Female'),
#               ('age', '60'),
#               ('travel', 'Yes - EGYPT; GERMANY; ISRAEL')]),
#  OrderedDict([('county', 'Volusia'),
#               ('gender', 'Male'),
#               ('age', '71'),
#               ('travel', 'Yes - EGYPT; JORDAN')]),
#  OrderedDict([('county', 'Volusia'),
#               ('gender', 'Male'),
#               ('age', '29'),
#               ('travel', 'Yes - TRINIDAD AND TOBAGO')]),
#  OrderedDict([('county', 'Volusia'),
#               ('gender', 'Female'),
#               ('age', '89'),
#               ('travel', 'No')])]

# %%
# https://services1.arcgis.com/CY1LXxl9zlJeBuRZ/ArcGIS/rest/services
# Out:
# [{'attributes': {'State': 'FL',
#    'OBJECTID': 66,
#    'County': 'Alachua',
#    'Counts': 1,
#    'Cases': 'Sex: Male , Age: 24 , Travel Related?  Yes - PORTUGAL',
#    'ObjectId2': 1}},
#  {'attributes': {'State': 'FL',
#    'OBJECTID': 62,
#    'County': 'Broward',
#    'Counts': 38,
#    'Cases': 'Sex: Female , Age: 20 , Travel Related?  Yes - IRELAND || Sex: Male , Age: 39 , Travel Related?  Unknown || Sex: Female , Age: 68 , Travel Related?  No || Sex: Male , Age: 59 , Travel Related?  No || Sex: Female , Age: 20 , Travel Related?  Yes - IRELAND || Sex: Male , Age: 75 , Travel Related?  No || Sex: Male , Age: 60 , Travel Related?  No || Sex: Male , Age: 21 , Travel Related?  Yes - ITALY; SPAIN || Sex: Female , Age: 83 , Travel Related?  No || Sex: Female , Age: 19 , Travel Related?  Yes - IRELAND || Sex: Male , Age: 61 , Travel Related?  Yes - ITALY || Sex: Male , Age: 67 , Travel Related?  No || Sex: Female , Age: 68 , Travel Related?  No || Sex: Male , Age: 60 , Travel Related?  Unknown || Sex: Male , Age: 70 , Travel Related?  Unknown || Sex: Male , Age: 63 , Travel Related?  No || Sex: Female , Age: 20 , Travel Related?  Yes - IRELAND || Sex: Female , Age: 19 , Travel Related?  Yes - IRELAND || Sex: Female , Age: 22 , Travel Related?  Yes - IRELAND || Sex: Male , Age: 83 , Travel Related?  Unknown || Sex: Male , Age: 30 , Travel Related?  Yes - FL; GA || Sex: Male , Age: 74 , Travel Related?  No || Sex: Male , Age: 65 , Travel Related?  Yes - DC || Sex: Male , Age: 36 , Travel Related?  No || Sex: Female , Age: 54 , Travel Related?  Unknown || Sex: Female , Age: 26 , Travel Related?  Yes - TRINIDAD AND TOBAGO || Sex: Male , Age: 65 , Travel Related?  No || Sex: Female , Age: 19 , Travel Related?  Yes - IRELAND || Sex: Male , Age: 65 , Travel Related?  No || Sex: Male , Age: 66 , Travel Related?  No || Sex: Female , Age: 27 , Travel Related?  No || Sex: Female , Age: 63 , Travel Related?  Unknown || Sex: Male , Age: 64 , Travel Related?  Yes - FRANCE; GA; NC; SPAIN || Sex: Female , Age: 52 , Travel Related?  Yes - FRANCE || Sex: Female , Age: 20 , Travel Related?  Yes - IRELAND || Sex: Male , Age: 58 , Travel Related?  No || Sex: Male , Age: 65 , Travel Related?  Unknown || Sex: Female , Age: 51 , Travel Related?  Unknown',
#    'ObjectId2': 2}},
#  {'attributes': {'State': 'FL',
#    'OBJECTID': 56,
#    'County': 'Charlotte',
#    'Counts': 1,
#    'Cases': 'Sex: Female , Age: 54 , Travel Related?  Yes - EGYPT; ISRAEL',
#    'ObjectId2': 3}},
#  {'attributes': {'State': 'FL',
#    'OBJECTID': 32,
#    'County': 'Citrus',
#    'Counts': 1,
#    'Cases': 'Sex: Female , Age: 60 , Travel Related?  Yes - FL; SWITZERLAND',
#    'ObjectId2': 4}},
#  {'attributes': {'State': 'FL',
#    'OBJECTID': 22,
#    'County': 'Clay',
#    'Counts': 3,
#    'Cases': 'Sex: Male , Age: 70 , Travel Related?  No || Sex: Female , Age: 55 , Travel Related?  No || Sex: Male , Age: 57 , Travel Related?  No',
#    'ObjectId2': 5}},
#  {'attributes': {'State': 'FL',
#    'OBJECTID': 47,
#    'County': 'Collier',
#    'Counts': 6,
#    'Cases': 'Sex: Female , Age: 64 , Travel Related?  Yes - EGYPT || Sex: Female , Age: 49 , Travel Related?  Unknown || Sex: Female , Age: 68 , Travel Related?  Yes - EGYPT || Sex: Male , Age: 28 , Travel Related?  Yes - ITALY || Sex: Male , Age: 76 , Travel Related?  Yes - NY || Sex: Male , Age: 73 , Travel Related?  Yes - EGYPT',
#    'ObjectId2': 6}},
#  {'attributes': {'State': 'FL',
#    'OBJECTID': 48,
#    'County': 'Dade',
#    'Counts': 23,
#    'Cases': 'Sex: Male , Age: 66 , Travel Related?  Unknown || Sex: Male , Age: 73 , Travel Related?  No || Sex: Female , Age: 77 , Travel Related?  Yes - EGYPT; IRAN (ISLAMIC REP. OF); UNITED ARAB EMIRATES || Sex: Male , Age: 42 , Travel Related?  Yes - FRANCE || Sex: Male , Age: 42 , Travel Related?  Yes - SPAIN || Sex: Male , Age: 56 , Travel Related?  Yes - IRAN (ISLAMIC REP. OF) || Sex: Male , Age: 28 , Travel Related?  No || Sex: Female , Age: 25 , Travel Related?  Yes - SPAIN || Sex: Male , Age: 43 , Travel Related?  Yes - UT || Sex: Female , Age: 39 , Travel Related?  Yes - FL; NY || Sex: Male , Age: 37 , Travel Related?  Yes - EL SALVADOR; FL; MEXICO; SPAIN || Sex: Female , Age: 45 , Travel Related?  No || Sex: Male , Age: 18 , Travel Related?  Unknown || Sex: Male , Age: 20 , Travel Related?  Yes - SPAIN || Sex: Female , Age: 66 , Travel Related?  Unknown || Sex: Male , Age: 29 , Travel Related?  Unknown || Sex: Female , Age: 58 , Travel Related?  Yes - ITALY; SPAIN || Sex: Male , Age: 56 , Travel Related?  Unknown || Sex: Male , Age: 51 , Travel Related?  No || Sex: Female , Age: 30 , Travel Related?  Unknown || Sex: Female , Age: 42 , Travel Related?  Unknown || Sex: Male , Age: 62 , Travel Related?  No || Sex: Male , Age: 39 , Travel Related?  Unknown',
#    'ObjectId2': 7}},
#  {'attributes': {'State': 'FL',
#    'OBJECTID': 36,
#    'County': 'Duval',
#    'Counts': 4,
#    'Cases': 'Sex: Male , Age: 88 , Travel Related?  No || Sex: Male , Age: 66 , Travel Related?  No || Sex: Male , Age: 83 , Travel Related?  No || Sex: Male , Age: 57 , Travel Related?  Yes - FL; UNKNOWN',
#    'ObjectId2': 8}},
#  {'attributes': {'State': 'FL',
#    'OBJECTID': 20,
#    'County': 'Hillsborough',
#    'Counts': 5,
#    'Cases': 'Sex: Female , Age: 29 , Travel Related?  Yes - ITALY || Sex: Female , Age: 32 , Travel Related?  Yes - CO || Sex: Male , Age: 47 , Travel Related?  Yes - CO || Sex: Male , Age: 17 , Travel Related?  No || Sex: Female , Age: 49 , Travel Related?  Yes - FL; IRELAND',
#    'ObjectId2': 9}},
#  {'attributes': {'State': 'FL',
#    'OBJECTID': 27,
#    'County': 'Lake',
#    'Counts': 1,
#    'Cases': 'Sex: Female , Age: 75 , Travel Related?  Yes - FL; NY',
#    'ObjectId2': 10}},
#  {'attributes': {'State': 'FL',
#    'OBJECTID': 46,
#    'County': 'Lee',
#    'Counts': 4,
#    'Cases': 'Sex: Male , Age: 77 , Travel Related?  No || Sex: Female , Age: 77 , Travel Related?  Yes - DOMINICAN REPUBLIC || Sex: Female , Age: 72 , Travel Related?  Unknown || Sex: Male , Age: 77 , Travel Related?  Yes - DOMINICAN REPUBLIC',
#    'ObjectId2': 11}},
#  {'attributes': {'State': 'FL',
#    'OBJECTID': 21,
#    'County': 'Manatee',
#    'Counts': 5,
#    'Cases': 'Sex: Male , Age: 63 , Travel Related?  No || Sex: Female , Age: 62 , Travel Related?  No || Sex: Female , Age: 81 , Travel Related?  Yes - EGYPT || Sex: Male , Age: 70 , Travel Related?  Unknown || Sex: Female , Age: 67 , Travel Related?  No',
#    'ObjectId2': 12}},
#  {'attributes': {'State': 'FL',
#    'OBJECTID': 54,
#    'County': 'Nassau',
#    'Counts': 1,
#    'Cases': 'Sex: Male , Age: 68 , Travel Related?  Yes - GERMANY; MA',
#    'ObjectId2': 13}},
#  {'attributes': {'State': 'FL',
#    'OBJECTID': 4,
#    'County': 'Okaloosa',
#    'Counts': 1,
#    'Cases': 'Sex: Female , Age: 61 , Travel Related?  Yes - CA; FL; MEXICO',
#    'ObjectId2': 14}},
#  {'attributes': {'State': 'FL',
#    'OBJECTID': 31,
#    'County': 'Orange',
#    'Counts': 4,
#    'Cases': 'Sex: Female , Age: 79 , Travel Related?  Unknown || Sex: Female , Age: 48 , Travel Related?  No || Sex: Male , Age: 41 , Travel Related?  No || Sex: Female , Age: 48 , Travel Related?  Unknown',
#    'ObjectId2': 15}},
#  {'attributes': {'State': 'FL',
#    'OBJECTID': 44,
#    'County': 'Osceola',
#    'Counts': 4,
#    'Cases': 'Sex: Male , Age: 31 , Travel Related?  Yes - BRAZIL || Sex: Female , Age: 47 , Travel Related?  Unknown || Sex: Male , Age: 48 , Travel Related?  Yes - SWITZERLAND || Sex: Male , Age: 54 , Travel Related?  No',
#    'ObjectId2': 16}},
#  {'attributes': {'State': 'FL',
#    'OBJECTID': 6,
#    'County': 'Palm Beach',
#    'Counts': 8,
#    'Cases': 'Sex: Male , Age: 37 , Travel Related?  Yes - NY || Sex: Female , Age: 76 , Travel Related?  Unknown || Sex: Female , Age: 59 , Travel Related?  Yes - NY || Sex: Male , Age: 62 , Travel Related?  Unknown || Sex: Male , Age: 65 , Travel Related?  Yes - NY || Sex: Male , Age: 73 , Travel Related?  Yes - Egypt; Germany || Sex: Male , Age: 74 , Travel Related?  Yes - BELGIUM; FL || Sex: Male , Age: 66 , Travel Related?  Unknown',
#    'ObjectId2': 17}},
#  {'attributes': {'State': 'FL',
#    'OBJECTID': 8,
#    'County': 'Pasco',
#    'Counts': 2,
#    'Cases': 'Sex: Male , Age: 67 , Travel Related?  Yes - FL; NY || Sex: Male , Age: 46 , Travel Related?  No',
#    'ObjectId2': 18}},
#  {'attributes': {'State': 'FL',
#    'OBJECTID': 34,
#    'County': 'Pinellas',
#    'Counts': 4,
#    'Cases': 'Sex: Male , Age: 58 , Travel Related?  Unknown || Sex: Male , Age: 64 , Travel Related?  Yes - EGYPT || Sex: Male , Age: 58 , Travel Related?  Unknown || Sex: Male , Age: 67 , Travel Related?  Yes - EGYPT',
#    'ObjectId2': 19}},
#  {'attributes': {'State': 'FL',
#    'OBJECTID': 50,
#    'County': 'Santa Rosa',
#    'Counts': 1,
#    'Cases': 'Sex: Male , Age: 71 , Travel Related?  Yes - EGYPT; ISRAEL; JORDAN',
#    'ObjectId2': 20}},
#  {'attributes': {'State': 'FL',
#    'OBJECTID': 57,
#    'County': 'Sarasota',
#    'Counts': 3,
#    'Cases': 'Sex: Male , Age: 87 , Travel Related?  No || Sex: Male , Age: 80 , Travel Related?  No || Sex: Female , Age: 50 , Travel Related?  Yes - NY',
#    'ObjectId2': 21}},
#  {'attributes': {'State': 'FL',
#    'OBJECTID': 30,
#    'County': 'Seminole',
#    'Counts': 4,
#    'Cases': 'Sex: Male , Age: 68 , Travel Related?  Yes - EGYPT; JORDAN || Sex: Female , Age: 68 , Travel Related?  Yes - EGYPT; JORDAN || Sex: Female , Age: 43 , Travel Related?  Unknown || Sex: Male , Age: 47 , Travel Related?  Unknown',
#    'ObjectId2': 22}},
#  {'attributes': {'State': 'FL',
#    'OBJECTID': 67,
#    'County': 'St. Johns',
#    'Counts': 1,
#    'Cases': 'Sex: Female , Age: 64 , Travel Related?  No',
#    'ObjectId2': 23}},
#  {'attributes': {'State': 'FL',
#    'OBJECTID': 25,
#    'County': 'Volusia',
#    'Counts': 6,
#    'Cases': 'Sex: Female , Age: 70 , Travel Related?  Yes - EGYPT; JORDAN || Sex: Female , Age: 66 , Travel Related?  Yes - EGYPT; GERMANY; ISRAEL || Sex: Female , Age: 60 , Travel Related?  Yes - EGYPT; GERMANY; ISRAEL || Sex: Male , Age: 71 , Travel Related?  Yes - EGYPT; JORDAN || Sex: Male , Age: 29 , Travel Related?  Yes - TRINIDAD AND TOBAGO || Sex: Female , Age: 89 , Travel Related?  No',
#    'ObjectId2': 24}}]
